# %%
import pandas as pd

# %%
data1 = pd.read_csv('./CSV/data_11.csv', names=['time [s]', 'intensity'], index_col=0, skiprows=1)
data2 = pd.read_csv('./CSV/data_28.csv', names=['time [s]', 'intensity'], index_col=0, skiprows=1)

# %%
data2.head()
# Out:
#           intensity
# time [s]
# 0.000000     125656
# 0.000403     126589
# 0.000807     126113
# 0.001210     123496
# 0.001614     125139

# %%
data1.plot()
data2.plot()
# Out:
# <AxesSubplot:xlabel='time [s]'>
